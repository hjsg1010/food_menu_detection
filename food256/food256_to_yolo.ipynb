# %%
import os
from PIL import Image

# %%
# modify the directories and class file to fit
datapath = './UECFOOD256/'
labelpath = 'labels'
classfilename = 'food256.names'

# %%
def convert_yolo_bbox(img_size, box):
    # img_bbox file is [0:img] [1:left X] [2:bottom Y] [3:right X] [4:top Y]
    dw = 1./img_size[0]
    dh = 1./img_size[1]
    x = (int(box[1]) + int(box[3]))/2.0
    y = (int(box[2]) + int(box[4]))/2.0
    w = abs(int(box[3]) - int(box[1]))
    h = abs(int(box[4]) - int(box[2]))
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    # Yolo bbox is center x, y and width, height
    return (x,y,w,h)

# %%
def generate_bbox_file(datapath, labelpath, classid, classname):
    dataDir = os.path.join(datapath, str(classid))
    labelDir = os.path.join(labelpath, str(classid))
    bb_filename = os.path.join(dataDir, 'bb_info.txt')
    if not os.path.exists(labelDir):
        os.makedirs(labelDir)
    with open(bb_filename) as fp:
        for line in fp.readlines():
            # img_bbox file is [0:img] [1:left X] [2:bottom Y] [3:right X] [4:top Y]
            img_bbox = line.strip('\n').split(' ')
            if img_bbox[0] != 'img':
                img_bbox_filename = os.path.join(dataDir, img_bbox[0]+'.txt')
                with open(img_bbox_filename, 'w') as f:
                    # [number of bbox]
                    # [left X] [top Y] [right X] [bottom Y] [class name]
                    f.write('1\n')
                    f.write('%s %s %s %s %s\n' %(img_bbox[1], img_bbox[4], img_bbox[3], img_bbox[2], classname))
                    f.close()

                image_filename = os.path.join(dataDir, img_bbox[0]+'.jpg')
                yolo_label_filename = os.path.join(labelDir, img_bbox[0]+'.txt')
                with open(yolo_label_filename, 'w') as f:
                    img = Image.open(image_filename)
                    yolo_bbox = convert_yolo_bbox(img.size, img_bbox)
                    if (yolo_bbox[2] > 1) or (yolo_bbox[3] > 1):
                        print("image %s bbox is " %(image_filename) + ' '.join(map(str, yolo_bbox)))
                    f.write(str(classid-1) + ' ' + ' '.join(map(str, yolo_bbox)) + '\n')
                    img.close()
                    f.close()
        fp.close()

# %%
classid = 0
classid2name = {}
if os.path.exists(classfilename):
    with open(classfilename) as cf:
        for line in cf.readlines():
            classname = line.strip('\n')
            classid = classid + 1
            classid2name[classid] = classname

for id in classid2name.keys():
    print("generating %d %s" %(id, classid2name[id]))
    generate_bbox_file(datapath, labelpath, id, classid2name[id])
# Out:
# generating 1 rice
# generating 2 eels on rice
# generating 3 pilaf
# generating 4 chicken-'n'-egg on rice
# generating 5 pork cutlet on rice
# generating 6 beef curry
# generating 7 sushi
# generating 8 chicken rice
# generating 9 fried rice
# generating 10 tempura bowl
# generating 11 bibimbap
# generating 12 toast
# generating 13 croissant
# generating 14 roll bread
# generating 15 raisin bread
# generating 16 chip butty
# generating 17 hamburger
# generating 18 pizza
# generating 19 sandwiches
# generating 20 udon noodle
# generating 21 tempura udon
# generating 22 soba noodle
# generating 23 ramen noodle
# generating 24 beef noodle
# generating 25 tensin noodle
# generating 26 fried noodle
# generating 27 spaghetti
# generating 28 Japanese-style pancake
# generating 29 takoyaki
# generating 30 gratin
# generating 31 sauteed vegetables
# generating 32 croquette
# generating 33 grilled eggplant
# generating 34 sauteed spinach
# generating 35 vegetable tempura
# generating 36 miso soup
# generating 37 potage
# generating 38 sausage
# generating 39 oden
# generating 40 omelet
# generating 41 ganmodoki
# generating 42 jiaozi
# generating 43 stew
# generating 44 teriyaki grilled fish
# generating 45 fried fish
# generating 46 grilled salmon
# generating 47 salmon meuniere
# generating 48 sashimi
# generating 49 grilled pacific saury
# generating 50 sukiyaki
# generating 51 sweet and sour pork
# generating 52 lightly roasted fish
# generating 53 steamed egg hotchpotch
# generating 54 tempura
# generating 55 fried chicken
# generating 56 sirloin cutlet
# generating 57 nanbanzuke
# generating 58 boiled fish
# generating 59 seasoned beef with potatoes
# generating 60 hambarg steak
# generating 61 steak
# generating 62 dried fish
# generating 63 ginger pork saute
# generating 64 spicy chili-flavored tofu
# generating 65 yakitori
# generating 66 cabbage roll
# generating 67 omelet
# generating 68 egg sunny-side up
# generating 69 natto
# generating 70 cold tofu
# generating 71 egg roll
# generating 72 chilled noodle
# generating 73 stir-fried beef and peppers
# generating 74 simmered pork
# generating 75 boiled chicken and vegetables
# generating 76 sashimi bowl
# generating 77 sushi bowl
# generating 78 fish-shaped pancake with bean jam
# generating 79 shrimp with chill source
# generating 80 roast chicken
# generating 81 steamed meat dumpling
# generating 82 omelet with fried rice
# generating 83 cutlet curry
# generating 84 spaghetti meat sauce
# generating 85 fried shrimp
# generating 86 potato salad
# generating 87 green salad
# generating 88 macaroni salad
# generating 89 Japanese tofu and vegetable chowder
# generating 90 pork miso soup
# generating 91 chinese soup
# generating 92 beef bowl
# generating 93 kinpira-style sauteed burdock
# generating 94 rice ball
# generating 95 pizza toast
# generating 96 dipping noodles
# generating 97 hot dog
# generating 98 french fries
# generating 99 mixed rice
# generating 100 goya chanpuru
# generating 101 green curry
# generating 102 okinawa soba
# generating 103 mango pudding
# generating 104 almond jelly
# generating 105 jjigae
# generating 106 dak galbi
# generating 107 dry curry
# generating 108 kamameshi
# generating 109 rice vermicelli
# generating 110 paella
# generating 111 tanmen
# generating 112 kushikatu
# generating 113 yellow curry
# generating 114 pancake
# generating 115 champon
# generating 116 crape
# generating 117 tiramisu
# generating 118 waffle
# generating 119 rare cheese cake
# generating 120 shortcake
# generating 121 chop suey
# generating 122 twice cooked pork
# generating 123 mushroom risotto
# generating 124 samul
# generating 125 zoni
# generating 126 french toast
# generating 127 fine white noodles
# generating 128 minestrone
# generating 129 pot au feu
# generating 130 chicken nugget
# generating 131 namero
# generating 132 french bread
# generating 133 rice gruel
# generating 134 broiled eel bowl
# generating 135 clear soup
# generating 136 yudofu
# generating 137 mozuku
# generating 138 inarizushi
# generating 139 pork loin cutlet
# generating 140 pork fillet cutlet
# generating 141 chicken cutlet
# generating 142 ham cutlet
# generating 143 minced meat cutlet
# generating 144 thinly sliced raw horsemeat
# generating 145 bagel
# generating 146 scone
# generating 147 tortilla
# generating 148 tacos
# generating 149 nachos
# generating 150 meat loaf
# image ./UECFOOD256/150/37571.jpg bbox is 0.6974248927038627 0.2785714285714286 1.3261802575107295 0.5228571428571429
# generating 151 scrambled egg
# generating 152 rice gratin
# generating 153 lasagna
# generating 154 Caesar salad
# generating 155 oatmeal
# generating 156 fried pork dumplings served in soup
# generating 157 oshiruko
# generating 158 muffin
# generating 159 popcorn
# generating 160 cream puff
# generating 161 doughnut
# generating 162 apple pie
# generating 163 parfait
# generating 164 fried pork in scoop
# generating 165 lamb kebabs
# generating 166 dish consisting of stir-fried potato, eggplant and green pepper
# generating 167 roast duck
# generating 168 hot pot
# generating 169 pork belly
# generating 170 xiao long bao
# generating 171 moon cake
# generating 172 custard tart
# generating 173 beef noodle soup
# generating 174 pork cutlet
# generating 175 minced pork rice
# generating 176 fish ball soup
# generating 177 oyster omelette
# generating 178 glutinous oil rice
# generating 179 trunip pudding
# generating 180 stinky tofu
# generating 181 lemon fig jelly
# generating 182 khao soi
# generating 183 Sour prawn soup
# generating 184 Thai papaya salad
# generating 185 boned, sliced Hainan-style chicken with marinated rice
# generating 186 hot and sour, fish and vegetable ragout
# generating 187 stir-fried mixed vegetables
# generating 188 beef in oyster sauce
# generating 189 pork satay
# generating 190 spicy chicken salad
# generating 191 noodles with fish curry
# generating 192 Pork Sticky Noodles
# generating 193 Pork with lemon
# generating 194 stewed pork leg
# generating 195 charcoal-boiled pork neck
# generating 196 fried mussel pancakes
# generating 197 Deep Fried Chicken Wing
# generating 198 Barbecued red pork in sauce with rice
# generating 199 Rice with roast duck
# generating 200 Rice crispy pork
# generating 201 Wonton soup
# generating 202 Chicken Rice Curry With Coconut
# generating 203 Crispy Noodles
# generating 204 Egg Noodle In Chicken Yellow Curry
# generating 205 coconut milk soup
# generating 206 pho
# generating 207 Hue beef rice vermicelli soup
# generating 208 Vermicelli noodles with snails
# generating 209 Fried spring rolls
# generating 210 Steamed rice roll
# generating 211 Shrimp patties
# generating 212 ball shaped bun with pork
# generating 213 Coconut milk-flavored crepes with shrimp and beef
# generating 214 Small steamed savory rice pancake
# generating 215 Glutinous Rice Balls
# generating 216 loco moco
# generating 217 haupia
# generating 218 malasada
# generating 219 laulau
# generating 220 spam musubi
# generating 221 oxtail soup
# generating 222 adobo
# generating 223 lumpia
# generating 224 brownie
# generating 225 churro
# generating 226 jambalaya
# generating 227 nasi goreng
# generating 228 ayam goreng
# generating 229 ayam bakar
# generating 230 bubur ayam
# generating 231 gulai
# generating 232 laksa
# generating 233 mie ayam
# generating 234 mie goreng
# generating 235 nasi campur
# generating 236 nasi padang
# generating 237 nasi uduk
# generating 238 babi guling
# generating 239 kaya toast
# generating 240 bak kut teh
# generating 241 curry puff
# generating 242 chow mein
# generating 243 zha jiang mian
# generating 244 kung pao chicken
# generating 245 crullers
# generating 246 eggplant with garlic sauce
# generating 247 three cup chicken
# generating 248 bean curd family style
# generating 249 salt & pepper fried shrimp with shell
# generating 250 baked salmon
# generating 251 braised pork meat ball with napa cabbage
# generating 252 winter melon soup
# generating 253 steamed spareribs
# generating 254 chinese pumpkin pie
# generating 255 eight treasure rice
# generating 256 hot & sour soup
